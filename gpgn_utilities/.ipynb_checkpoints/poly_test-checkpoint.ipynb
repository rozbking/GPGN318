# %%
import sys
sys.path.insert(0, "../gravity/")

from IPython.display import display
from ipywidgets import Output
from poly_interact import PolygonEditor

from grav_interact import gpoly

import plotly.graph_objects as go
import numpy as np
import ipywidgets as widgets
# Out:
#   File "poly_interact.py", line 11
#     return f"rgb({random.randint(80,220)}, {random.randint(80,220)}, {random.randint(80,220)})"
#                                                                                               ^
# SyntaxError: invalid syntax

# %%
obs_x = np.linspace(-100, 100, 51)
obs_z = np.zeros_like(obs_x)
obs = np.c_[obs_x, obs_z]

dike = [[-15, -400],[-15, -10],[15, -10],[15, -400]]
gz = -gpoly(obs, dike, 1.0)

editor = PolygonEditor(width=1000, height=400, points=obs)
#editor.add_polygons(dike)

fig = go.FigureWidget(data=[go.Scatter(x=obs_x, y=gz, mode='lines')])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-16acb61782cb> in <module>()
# ----> 1 obs_x = np.linspace(-100, 100, 51)
#       2 obs_z = np.zeros_like(obs_x)
#       3 obs = np.c_[obs_x, obs_z]
#       4
#       5 dike = [[-15, -400],[-15, -10],[15, -10],[15, -400]]
#
# NameError: name 'np' is not defined

# %%
editor
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0d44778d72ea> in <module>()
# ----> 1 editor
#
# NameError: name 'editor' is not defined

# %%
# A slider that controls frequency of sine wave
def update(polys):
    gz = 0.0
    for poly in polys:
        gz -= gpoly(obs, poly, 1.0)

    with fig.batch_update():  # more efficient batch updates
        fig.data[0].y = gz

# %%
editor.on_poly_update(update)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f73b127f39f7> in <module>()
# ----> 1 editor.on_poly_update(update)
#
# NameError: name 'editor' is not defined

# %%
# Use FigureWidget
w = widgets.VBox([fig, editor], layout=widgets.Layout(max_height="100%"))
widgets.HBox([w], layout=widgets.Layout(justify_content="center", width="100%"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6e32500c614a> in <module>()
#       1 # Use FigureWidget
# ----> 2 w = widgets.VBox([fig, editor], layout=widgets.Layout(max_height="100%"))
#       3 widgets.HBox([w], layout=widgets.Layout(justify_content="center", width="100%"))
#
# NameError: name 'widgets' is not defined

# %%
editor.load_btn.value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-0b70960c2a65> in <module>()
# ----> 1 editor.load_btn.value
#
# NameError: name 'editor' is not defined

# %%
editor.load_btn.value[0].
# Out:
#   File "<ipython-input-8-83893098c81c>", line 1
#     editor.load_btn.value[0].
#                              ^
# SyntaxError: invalid syntax
